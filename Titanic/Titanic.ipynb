# %%
#import libraries and load dataset
import pandas as pd
import numpy as np
df=pd.read_csv("Titanic Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
print(df.tail())
print(df.shape)
print(df.columns)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C
# (418, 12)
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
# ...

# %%
#Data types and null info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
#Statistical Summary
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass              Name   Sex  \
# count    418.000000  418.000000  418.000000               418   418
# unique          NaN         NaN         NaN               418     2
# top             NaN         NaN         NaN  Kelly, Mr. James  male
# freq            NaN         NaN         NaN                 1   266
# mean    1100.500000    0.363636    2.265550               NaN   NaN
# std      120.810458    0.481622    0.841838               NaN   NaN
# min      892.000000    0.000000    1.000000               NaN   NaN
# 25%      996.250000    0.000000    1.000000               NaN   NaN
# 50%     1100.500000    0.000000    3.000000               NaN   NaN
# 75%     1204.750000    1.000000    3.000000               NaN   NaN
# max     1309.000000    1.000000    3.000000               NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare  \
# count   332.000000  418.000000  418.000000       418  417.000000
# ...

# %% [markdown]
# #Identify Feature Types
# Numerical: Age, Fare, SibSp, Parch, PassengerId
# Categorical: Sex, Embarked, Cabin, Ticket, Name
# Binary: Survived
# Ordinal: Pclass

# %%
#Check the unique values
for col in ['Sex', 'Embarked', 'Pclass', 'Survived']:
    print(col, ":", df[col].unique())
# Out:
# Sex : ['male' 'female']
# Embarked : ['Q' 'S' 'C']
# Pclass : [3 2 1]
# Survived : [0 1]

# %%
#Missing Values Analysis
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# Observations from missing values
# Age has moderate missing values → should be imputed (median recommended)
# Fare has minimal missing values → can fill with median or mean
# Cabin missing for 327 passengers → more than 50% → may be dropped or transformed
# Other fields have zero missing values → easy for modeling

# %% [markdown]
# #Target Variable Identification
# Target Variable = Survived (0 = Died, 1 = Survived)

# %% [markdown]
# #Summary
# Target variable present → Yes
# Missing values present → needs preprocessing
# Balanced? → Slightly imbalanced but manageable
# Suitable for ML → YES
